# %% [markdown]
# # Explore PriceCatcher
# Initial exploration notebook for remote PriceCatcher parquet files and lookup tables.

# %%
from pathlib import Path
import pandas as pd

ROOT = Path.cwd().parents[0] if Path.cwd().name == 'notebooks' else Path.cwd()
lookup_item = pd.read_parquet(ROOT / 'data' / 'lookup' / 'lookup_item.parquet')
lookup_item.head()

# %%
basket_items = [
    'Beras Putih Super Tempatan',
    'Ayam Proses Standard',
    'Telur Ayam Gred A',
    'Minyak Masak',
    'Gula Putih',
    'Tepung Gandum',
]
lookup_item[lookup_item['item'].isin(basket_items)][['item_code', 'item', 'unit']].sort_values('item')
