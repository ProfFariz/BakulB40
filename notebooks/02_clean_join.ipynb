# %% [markdown]
# # Clean And Join
# Prototype notebook to validate the cleaned analytical table before exporting parquet.

# %%
from pathlib import Path
import pandas as pd

ROOT = Path.cwd().parents[0] if Path.cwd().name == 'notebooks' else Path.cwd()
clean = pd.read_parquet(ROOT / 'data' / 'processed' / 'pricecatcher_b40_12bulan.parquet')
clean.head()

# %%
clean.groupby(['state', 'district', 'item']).agg(avg_price=('price', 'mean'), observations=('price', 'size')).reset_index().head(20)
