# %% [markdown]
# # Basket Analysis
# Use processed outputs to answer the five main business questions.

# %%
from pathlib import Path
import json
import pandas as pd

ROOT = Path.cwd().parents[0] if Path.cwd().name == 'notebooks' else Path.cwd()
summary = pd.read_csv(ROOT / 'data' / 'processed' / 'basket_cost.csv')
inflation = pd.read_csv(ROOT / 'data' / 'processed' / 'inflation_by_item.csv')
insights = json.loads((ROOT / 'data' / 'processed' / 'insights.json').read_text(encoding='utf-8'))
summary.head()

# %%
summary.groupby('state')['burden_pct'].mean().sort_values(ascending=False)

# %%
inflation.sort_values(['bulan', 'monthly_change_pct'], ascending=[True, False]).tail(12)

# %%
insights
